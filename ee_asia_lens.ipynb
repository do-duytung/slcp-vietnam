# %%
import ee
import folium

ee.Authenticate()
ee.Initialize()


def add_ee_layer(self, ee_image_object, vis_params, name):
  map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
  folium.raster_layers.TileLayer(
      tiles=map_id_dict['tile_fetcher'].url_format,
      attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
      name=name,
      overlay=True,
      control=True
  ).add_to(self)

folium.Map.add_ee_layer = add_ee_layer

# %%
import ee
import numpy as np
import matplotlib.pyplot as plt

ee.Authenticate()
ee.Initialize()

# Load the MERRA-2 precipitation data
dataset = ee.ImageCollection("NASA/GSFC/MERRA/aer/2")

# Filter the data to the current date
current_date = ee.Date('2023-05-01')
filtered_dataset = dataset.filterDate(current_date, current_date)

# Get the precipitation data for a specific location
location = ee.Geometry.Point([37.775, -122.418])
precipitation_data = filtered_dataset.getRegion(location)

# # Convert the precipitation data to a NumPy array
# precipitation_array = precipitation_data.toArray()

# # Plot the precipitation distribution map
# plt.imshow(precipitation_array, cmap='jet')
# plt.title('Precipitation Distribution Map')
# plt.show()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ZgDBbmy3kN5d0SE_hKEG8AjM2Jq3FXL5ZsWlRd4wtDs&tc=mLMGClg-qcugn--L3uLMF_CDXl4HWxbOmi-DfnafPyA&cc=tXDLvUBVxR4zBOM2ZECSs2oA0j0N2-YYRW_I5K5d7y8>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ZgDBbmy3kN5d0SE_hKEG8AjM2Jq3FXL5ZsWlRd4wtDs&tc=mLMGClg-qcugn--L3uLMF_CDXl4HWxbOmi-DfnafPyA&cc=tXDLvUBVxR4zBOM2ZECSs2oA0j0N2-YYRW_I5K5d7y8</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.
# ...

# %%
import matplotlib.pyplot as plt

# Load the MERRA-2 precipitation data
dataset = ee.ImageCollection("NASA/GSFC/MERRA/aer/2")

# Filter the data to the current date
current_date = ee.Date('2022-05-01')
filtered_dataset = dataset.Filter.date(current_date, current_date)

BC_data = filtered_dataset.select('BCFLUXU')
# Plot a distribution map of the BC data
filtered_dataset.getInfo()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 8
#       6 # Filter the data to the current date
#       7 current_date = ee.Date('2022-05-01')
# ----> 8 filtered_dataset = dataset.Filter.date(current_date, current_date)
#      10 BC_data = filtered_dataset.select('BCFLUXU')
#      11 # Plot a distribution map of the BC data
#
# AttributeError: 'ImageCollection' object has no attribute 'Filter'

# %%
dataset = ee.ImageCollection('NASA/GSFC/MERRA/aer/2') \
                  .filter(ee.Filter.date('2022-02-01', '2022-02-02'))

black_carbon_column_u_wind_mass_flux = dataset.select('BCFLUXU')
black_carbon_column_u_wind_mass_flux.getInfo()
# Out:
# {'type': 'ImageCollection',
#  'bands': [],
#  'version': 1684891242368615,
#  'id': 'NASA/GSFC/MERRA/aer/2',
#  'features': [{'type': 'Image',
#    'bands': [{'id': 'BCFLUXU',
#      'data_type': {'type': 'PixelType', 'precision': 'float'},
#      'dimensions': [576, 361],
#      'crs': 'EPSG:4326',
#      'crs_transform': [0.625, 0, -180.5, 0, 0.5, -90.5]}],
#    'version': 1668670077816417,
#    'id': 'NASA/GSFC/MERRA/aer/2/2022020100',
#    'properties': {'system:time_start': 1643673600000,
#     'hour': 0,
#     'month': 2,
#     'year': 2022,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[-180, -90],
#       [180, -90],
#       [180, 90],
#       [-180, 90],
#       [-180, -90]]},
#     'system:time_end': 1643677200000,
#     'system:asset_size': 31678992,
#     'day': 1,
#     'system:index': '2022020100'}},
#   {'type': 'Image',
#    'bands': [{'id': 'BCFLUXU',
#      'data_type': {'type': 'PixelType', 'precision': 'float'},
# ...
